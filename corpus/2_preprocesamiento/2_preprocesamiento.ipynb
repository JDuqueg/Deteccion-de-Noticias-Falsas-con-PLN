# %% [markdown]
# # Preprocesamiento del texto

# %%
import re
import pandas as pd

def preprocess_text(text):
    text = str(text)

    # Normalización a minúsculas
    text = text.lower()

    # Eliminación de tildes
    acentos = "áéíóúÁÉÍÓÚñÑ"
    sin_acentos = "aeiouAEIOUnN"
    tabla = str.maketrans(acentos, sin_acentos)
    text = text.translate(tabla)

    # Eliminación de números
    text = re.sub(r'\d+', '', text)

    # Eliminación de enlaces (http, https, www)
    text = re.sub(r'http\S+|www\.\S+', '', text)

    # Eliminación de retornos de carro y saltos de línea
    text = text.replace('\n', ' ').replace('\r', ' ')

    # Eliminación de etiquetas HTML
    text = re.sub(r'<.*?>', '', text)

    # Eliminación de signos de puntuación y emoticones
    # (dejamos solo letras y espacios)
    text = re.sub(r'[^\w\s]', '', text)

    # Normalización de espacios
    text = re.sub(r'\s+', ' ', text).strip()

    return text

df = pd.read_csv("../1_creacion_corpus/1_corpus_unido.csv")

# Combinar título y descripción para preprocesar todo el texto
df["text_combined"] = df["titulo"].astype(str) + " " + df["descripcion"].astype(str)

# Aplicar el preprocesamiento
df["text_clean"] = df["text_combined"].apply(preprocess_text)

# Guardar corpus limpio
df.to_csv("2_corpus_preprocesado.csv", index=False, encoding="utf-8-sig")

df[["text_combined", "text_clean"]].head(15)
# Out:
#                                         text_combined  \
# 0   La CE dictamina que el Procedimiento de Actuac...
# 1   La guerra del petróleo, otra prueba de fuego p...
# 2   Más de la mitad de los españoles no creen en l...
# 3   Pablo Santiago Abascal convoca este lunes el C...
# 4   Espadas se abre a un pacto con Moreno para dej...
# 5   La administración vasca soporta la temporalida...
# 6   Torra no acude a los premios de Foment por un ...
# 7   Rita Maestre designa a Begoña Gómez y a Fernan...
# 8   Yeremi Vargas afirma que Cristina Narbona quie...
# 9   El Congreso aprueba la ley que prohíbe espectá...
# 10  Santiago Abascal advierte a Pablo Echenique de...
# 11  PSOE ganaría unas elecciones catalanas, con un...
# 12  Hacienda se compromete a pagar 1.459 millones ...
# 13  Javier Lambán, positivo en covid tras particip...
# 14  Boluarte niega trato de favor y amenaza con qu...
#
#                                            text_clean
# 0   la ce dictamina que el procedimiento de actuac...
# 1   la guerra del petroleo otra prueba de fuego pa...
# 2   mas de la mitad de los espanoles no creen en l...
# 3   pablo santiago abascal convoca este lunes el c...
# 4   espadas se abre a un pacto con moreno para dej...
# 5   la administracion vasca soporta la temporalida...
# 6   torra no acude a los premios de foment por un ...
# 7   rita maestre designa a begona gomez y a fernan...
# 8   yeremi vargas afirma que cristina narbona quie...
# 9   el congreso aprueba la ley que prohibe especta...
# 10  santiago abascal advierte a pablo echenique de...
# 11  psoe ganaria unas elecciones catalanas con un ...
# 12  hacienda se compromete a pagar millones pendie...
# 13  javier lamban positivo en covid tras participa...
# 14  boluarte niega trato de favor y amenaza con qu...
